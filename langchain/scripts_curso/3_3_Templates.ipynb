# %% [markdown]
# # Setup

# %%
from langchain_openai import ChatOpenAI,OpenAI
from langchain.prompts import PromptTemplate,ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
import os
import yaml

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
os.environ['OPENAI_API_KEY'] = config['OPENAI_API_KEY']

# %% [markdown]
# # Completion

# %%
template = '''
Você é um analista financeiro.
Escreva um relatório financeiro detalhado para a empresa "{empresa}" para o período {periodo}.

O relatório deve ser escrito em {idioma} e incluir as seguintes análises:
{analises}

Certifique-se de fornecer insights e conclusões para cada seção.
'''

# %%
prompt_template = PromptTemplate.from_template(template=template)

# %%
empresa = 'ACME Corp'
periodo = 'Q1 2024'
idioma = 'Português'
analises = [
    "Análise do Balanço Patrimonial",
    "Análise do Fluxo de Caixa",
    "Análise de Tendências",
    "Análise de Receita e Lucro",
    "Análise de Posição de Mercado"
]
analises_text = "\n".join([f"- {analise}" for analise in analises])

# %%
print(analises_text)
# Out:
# - Análise do Balanço Patrimonial
# - Análise do Fluxo de Caixa
# - Análise de Tendências
# - Análise de Receita e Lucro
# - Análise de Posição de Mercado

# %%
prompt = prompt_template.format(
    empresa=empresa,
    periodo=periodo,
    idioma=idioma,
    analises=analises_text
)
print("Prompt Gerado:\n", prompt)
# Out:
# Prompt Gerado:
#
# Você é um analista financeiro.
# Escreva um relatório financeiro detalhado para a empresa "ACME Corp" para o período Q1 2024.
#
# O relatório deve ser escrito em Português e incluir as seguintes análises:
# - Análise do Balanço Patrimonial
# - Análise do Fluxo de Caixa
# - Análise de Tendências
# - Análise de Receita e Lucro
# - Análise de Posição de Mercado
#
# Certifique-se de fornecer insights e conclusões para cada seção.

# %%
openai = OpenAI(model_name='gpt-3.5-turbo-instruct',max_tokens=2000) #max 4096

response = openai.invoke(prompt)
print("Saída do LLM:\n", response)
# Out:
# Saída do LLM:
#
# Relatório Financeiro - ACME Corp - Q1 2024
#
# Análise do Balanço Patrimonial:
#
# O Balanço Patrimonial da ACME Corp para o primeiro trimestre de 2024 apresenta uma situação financeira estável e sólida. Os ativos totais da empresa aumentaram em 5% em comparação com o trimestre anterior, atingindo o valor de R$500.000. Isso se deve principalmente ao aumento nos investimentos em equipamentos e tecnologias, que são essenciais para o crescimento e a competitividade da empresa no mercado.
#
# Os passivos também aumentaram em 3%, chegando a um total de R$300.000. No entanto, isso não afetou negativamente a posição financeira da empresa, pois os ativos ainda superam os passivos, resultando em um patrimônio líquido de R$200.000.
#
# Análise do Fluxo de Caixa:
#
# O fluxo de caixa da ACME Corp para o primeiro trimestre de 2024 apresenta um saldo positivo de R$50.000. Isso indica que a empresa está gerando mais caixa do que está gastando, o que é um sinal positivo para sua saúde financeira. Além disso, o fluxo de caixa operacional aumentou em 8%, o que indica uma melhoria na eficiência das operações da empresa.
#
# No entanto, é importante notar que o fluxo de caixa de investimentos e financiamentos apresentou um saldo negativo, devido ao aumento nos investimentos de capital e ao pagamento de empréstimos. Isso significa que a empresa precisa ser cautelosa com seus gastos e garantir que tenha fluxo de caixa suficiente para cobrir esses compromissos.
#
# Análise de Tendências:
#
# A ACME Corp tem mostrado um crescimento constante nos últimos anos e esse padrão continua no primeiro trimestre de 2024. Tanto os ativos quanto o patrimônio líquido da empresa apresentaram um aumento em relação ao trimestre anterior e ao mesmo período do ano anterior. Isso indica que a empresa está em uma trajetória de crescimento saudável e sustentável.
#
# No entanto, é importante notar que os passivos também estão aumentando, o que pode ser um sinal de preocupação caso não sejam gerenciados adequadamente. A empresa deve se concentrar em manter um equilíbrio saudável entre os ativos e os passivos para garantir sua estabilidade financeira a longo prazo.
#
# Análise de Receita e Lucro:
#
# A receita da ACME Corp para o primeiro trimestre de 2024 foi de R$150.000, um aumento de 10% em relação ao trimestre anterior e de 15% em relação ao mesmo período do ano anterior. Esse aumento pode ser atribuído a um aumento nas vendas de produtos e serviços, bem como a uma estratégia de preços eficaz.
#
# Além disso, a empresa obteve um lucro de R$30.000, o que representa uma margem de lucro de 20%. Isso é um sinal positivo, pois indica que a empresa está gerando lucro de suas operações e tem potencial para expandir suas operações no futuro.
#
# Análise de Posição de Mercado:
#
# A ACME Corp é uma empresa bem estabelecida no mercado, com uma forte presença em seu setor. No entanto, há uma concorrência crescente no mercado, o que pode ameaçar sua posição. A empresa deve continuar a inovar e investir em tecnologias para se manter competitiva e garantir sua participação no mercado.
#
# Conclusão:
#
# Com base na análise financeira detalhada acima, podemos concluir que a ACME Corp teve um desempenho sólido no primeiro trimestre de 2024. A empresa apresentou um crescimento constante, gerou lucros e mantém uma posição financeira estável. No entanto, é importante que a empresa continue a gerenciar seus gastos e a investir em tecnologias para manter sua posição competitiva no mercado.

# %% [markdown]
# # Chat

# %%
#equivalência aos roles: system: system, Human: user, AI: assistant
chat_template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(content='Você deve estruturar suas respostas de acordo com o método de análise de negócios, garantindo clareza e concisão.'),
        HumanMessagePromptTemplate.from_template('Por favor, gere um relatório detalhado sobre a indústria de tecnologia na região "{regiao}".'),
        AIMessage(content='Claro, vou começar coletando informações sobre a região e analisando os dados disponíveis.'),
        HumanMessage(content='Certifique-se de incluir uma análise SWOT e uma previsão de crescimento para os próximos 5 anos.'),
        AIMessage(content='Entendido. Aqui está o relatório completo:')
    ]
)

# %%
prompt_gerado = chat_template.format_messages(regiao='América Latina')
print(prompt_gerado)
# Out:
# [SystemMessage(content='Você deve estruturar suas respostas de acordo com o método de análise de negócios, garantindo clareza e concisão.'), HumanMessage(content='Por favor, gere um relatório detalhado sobre a indústria de tecnologia na região "América Latina".'), AIMessage(content='Claro, vou começar coletando informações sobre a região e analisando os dados disponíveis.'), HumanMessage(content='Certifique-se de incluir uma análise SWOT e uma previsão de crescimento para os próximos 5 anos.'), AIMessage(content='Entendido. Aqui está o relatório completo:')]

# %%
openai = ChatOpenAI(model_name='gpt-3.5-turbo')
response = openai.invoke(prompt_gerado)
print("Saída do LLM:\n", response.content)
# Out:
# Saída do LLM:
#  **Relatório sobre a Indústria de Tecnologia na América Latina**
#
# **1. Contexto da Região:**
# A América Latina é uma região diversificada, composta por países em diferentes estágios de desenvolvimento econômico. A penetração da tecnologia na região tem crescido significativamente nos últimos anos, impulsionada pela expansão da conectividade e pelo aumento do acesso à internet.
#
# **2. Análise SWOT:**
#
# - **Forças (Strengths):**
#    - Crescente população jovem, com alto potencial para adoção de tecnologia.
#    - Aumento dos investimentos em infraestrutura de telecomunicações.
#    - Ecossistema de startups em expansão em países como Brasil, México e Colômbia.
#
# - **Fraquezas (Weaknesses):**
#    - Desigualdade de acesso à tecnologia entre áreas urbanas e rurais.
#    - Infraestrutura precária em alguns países, dificultando a expansão da tecnologia.
#    - Baixo investimento em pesquisa e desenvolvimento em comparação com outras regiões.
#
# - **Oportunidades (Opportunities):**
#    - Crescimento do mercado de e-commerce e serviços digitais.
#    - Aumento da demanda por soluções de tecnologia em setores como educação, saúde e finanças.
#    - Potencial para parcerias estratégicas com empresas globais de tecnologia.
#
# - **Ameaças (Threats):**
#    - Instabilidade política e econômica em alguns países da região.
#    - Vulnerabilidades cibernéticas e questões de segurança de dados.
#    - Concorrência de mercados emergentes com ecossistemas de tecnologia mais desenvolvidos.
#
# **3. Previsão de Crescimento para os Próximos 5 Anos:**
# Com base na tendência atual de aumento da adoção de tecnologia na região, é esperado que a indústria de tecnologia na América Latina continue a crescer nos próximos anos. A expansão da conectividade, o desenvolvimento de soluções inovadoras e o aumento dos investimentos em tecnologia devem impulsionar o crescimento do setor.
#
# Estima-se que o mercado de tecnologia na América Latina cresça a uma taxa anual de aproximadamente 8% nos próximos 5 anos. O crescimento será impulsionado principalmente pelo aumento da demanda por serviços digitais, pela expansão do mercado de dispositivos móveis e pela crescente digitalização de diversos setores da economia.
#
# **Conclusão:**
# A indústria de tecnologia na América Latina apresenta oportunidades significativas de crescimento, impulsionadas pela crescente demanda por soluções digitais e pela expansão da conectividade. No entanto, desafios como a desigualdade de acesso e a infraestrutura precária ainda precisam ser superados para que a região atinja seu pleno potencial no setor de tecnologia. A colaboração entre governos, empresas e instituições de pesquisa será fundamental para impulsionar a inovação e o desenvolvimento tecnológico na região.
