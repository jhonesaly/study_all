# %% [markdown]
# # Setup

# %%
from openai import OpenAI
import os
import yaml

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
    
os.environ['OPENAI_API_KEY'] = config['OPENAI_API_KEY']

# %% [markdown]
# # Completion

# %%
client = OpenAI()
response = client.completions.create(
  model="gpt-3.5-turbo-instruct",
  prompt="Crie uma canção contendo apenas uma estrofe."
)

# %%
print(response)
# Out:
# Completion(id='cmpl-Delj11gIb6WUmeKnZBZCxu2OXPXwY', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text='\n\nSeu sorriso brilha como o sol\nE o toque')], created=1778608947, model='gpt-3.5-turbo-instruct:20230824-v2', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=13, total_tokens=29))

# %%
message = (response.choices[0].text)
print(message)
# Out:
# Seu sorriso brilha como o sol
# E o toque
