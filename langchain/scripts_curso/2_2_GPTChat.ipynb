# %% [markdown]
# # Setup

# %%
from openai import OpenAI
import os
import yaml

# %%
with open('config.yaml', 'r') as config_file:
    config = yaml.safe_load(config_file)
    
os.environ['OPENAI_API_KEY'] = config['OPENAI_API_KEY']

# %% [markdown]
# # Chat Básico

# %%
client = OpenAI()
model = "gpt-3.5-turbo"

response = client.chat.completions.create(
  model=model,
  messages=[
    {"role": "user", "content": "Conte uma Piada!"}
  ]
)

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-Delv3GTJqS2Jq1nj1NV6bmtHLAox5', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Por que o jacaré foi ao psicólogo?\nPorque ele tinha muitos crocodilos na cabeça!', role='assistant', function_call=None, tool_calls=None, refusal=None, annotations=[]))], created=1778609693, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=26, prompt_tokens=13, total_tokens=39, prompt_tokens_details={'cached_tokens': 0, 'audio_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}))

# %%
print(type(response))
# Out:
# <class 'openai.types.chat.chat_completion.ChatCompletion'>

# %%
message = (response.choices[0].message.content)
print(message)
# Out:
# Por que o jacaré foi ao psicólogo?
# Porque ele tinha muitos crocodilos na cabeça!

# %% [markdown]
# # Roles

# %%
response = client.chat.completions.create(
  model=model,
  messages=[
    {"role": "system", "content": "You are a fictional investment assistant."},
    {"role": "user", "content": "What is the best low-risk investment you recommend for this year?"}
  ]
)

# %%
message = (response.choices[0].message.content)
print(message)
# Out:
# For a low-risk investment option this year, I recommend looking into high-quality bonds or bond funds. Treasury bonds or highly-rated corporate bonds are generally considered low-risk investments as they provide steady interest payments and are less volatile compared to stocks. You might also consider bond funds that invest in a diversified portfolio of bonds to spread out risk further. It's always a good idea to consult with a financial advisor before making any investment decisions to ensure it aligns with your financial goals and risk tolerance.

# %%
response = client.chat.completions.create(
  model=model,
  messages=[
    {"role": "assistant", "content": message},
    {"role": "user", "content": "What are the risks related to Government bonds?"}
  ]
)

# %%
print(response.choices[0].message.content)
# Out:
# While government bonds are generally considered lower-risk investments compared to other types of bonds or equities, they do still carry some risks that investors should be aware of:
#
# 1. Interest Rate Risk: As interest rates rise, the value of existing bonds typically falls. This is because new bonds are issued with higher interest rates, making older bonds less attractive. Conversely, falling interest rates can cause bond prices to rise.
#
# 2. Inflation Risk: If inflation rises, the purchasing power of the fixed interest payments from government bonds may be eroded. This means that the real return on investment (adjusted for inflation) could be lower than expected.
#
# 3. Credit Risk: While government bonds are generally considered safe because they are backed by the full faith and credit of the government, there is still a small risk of default. This risk is typically higher for bonds issued by lower-rated governments or in times of economic instability.
#
# 4. Liquidity Risk: Some government bonds may have limited liquidity, especially if they are not actively traded in the market. This could make it difficult to sell the bonds at a desired price or time.
#
# 5. Reinvestment Risk: When a bond reaches maturity or is called, investors may face the challenge of reinvesting the proceeds at a lower interest rate environment, potentially reducing their overall return.
#
# While government bonds are considered relatively safe, it's important to understand these risks and diversify your portfolio accordingly to mitigate them.

# %% [markdown]
# ## Hiper Parâmetros

# %%
response = client.chat.completions.create(
  model=model,
  frequency_penalty=1,
  presence_penalty = 1,
  temperature =  1 ,
  max_tokens=500,
  n = 2 ,
  seed = 123,
  #stop = ["shadows","mortal "],
  messages=[
    {"role": "system", "content": "You are a depressed and disillusioned poet."},
    {"role": "user", "content": "Compose a poem about the ephemerality of existence."}
  ]
)

# %%
print(response.choices[0].message.content)
print(" -------------------------")
print(response.choices[1].message.content)
# Out:
# In the hush of twilight's fading sigh,
# We dance upon the edge of time,
# Our souls but fleeting sparks that fly
# Beneath the vast and starry sky.
#
# Our dreams, like shadows, swiftly fade,
# And whispers drift on fleeting winds,
# In this world where nothing's stayed
# But memories that slowly rescind.
#
# Oh, how transient this life we lead,
# A fragile thread in fate's cruel hand,
# Where moments slip like grains of sand
# And all we love will one day recede.
#
# So let us mourn our brief sojourn here,
# For naught endures beneath the sun.
# May we find solace in our fear
# Of what will be once all is done.
#
# Embrace the beauty of each passing day,
# Though bittersweet it slips away.
#  -------------------------
# In this fleeting world of shadows cast,
# We dance upon the thin line, breathing our last.
# Time slips through our fingers like grains of sand,
# Leaving us broken and lost in a barren land.
#
# Our dreams crumble into dust with each passing day,
# And we watch as everything we hold dear wanes away.
# The laughter once shared now echoes hollow and cold,
# As the specter of mortality holds us in its hold.
#
# Life is but a vapor, fading before our eyes,
# Leaving behind memories that slowly die.
# We chase after illusions, searching for meaning in vain,
# Only to realize that all efforts are spent in pain.
#
# The sun sets on hopes never realized or gained,
# Leaving us drowning in sorrow, battered and strained.
# For what is left but emptiness and despair?
# As we confront the truth that life is unfairly unfair.
#
# So let us embrace the ephemeral nature of it all,
# And find solace in knowing that even the strongest fall.
# For in this transient existence, there lies beauty untold,
# In accepting our impermanence, we find courage bold.
